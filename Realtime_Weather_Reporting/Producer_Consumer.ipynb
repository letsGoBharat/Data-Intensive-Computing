# %% [markdown]
# # ID2221 Project

# %% [markdown]
# ### Setup:
# - start Kafka broker in Terminal and create topic "weather"

# %%
from kafka import KafkaProducer, KafkaConsumer
from json import dumps
import time
import json
import requests
import uuid
from pprint import pprint

# %%
#personal API key
API_KEY = 'fb68dc4a03f52b61ef70e6b9612e2aff'                    

city = 'Stockholm'
lat = 59.3326
lon = 18.0649

# %%
request = requests.get(f'https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&appid={API_KEY}')
# request = requests.get(f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}')
#request = requests.get(f'https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&exclude=daily&appid={API_KEY}')
#request = requests.get(f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}')

# %%
json_data = json.loads(request.text)
pprint(json_data)
# Out:
# {'current': {'clouds': 29,
#              'dew_point': 269.33,
#              'dt': 1603124242,
#              'feels_like': 271.99,
#              'humidity': 55,
#              'pressure': 1012,
#              'sunrise': 1603085741,
#              'sunset': 1603121359,
#              'temp': 277.05,
#              'uvi': 0.78,
#              'visibility': 10000,
#              'weather': [{'description': 'scattered clouds',
#                           'icon': '03n',
#                           'id': 802,
#                           'main': 'Clouds'}],
#              'wind_deg': 290,
#              'wind_speed': 3.6},
#  'daily': [{'clouds': 0,
#             'dew_point': 269.06,
#             'dt': 1603101600,
#             'feels_like': {'day': 270.74,
#                            'eve': 271.5,
#                            'morn': 269.71,
#                            'night': 270.81},
#             'humidity': 67,
#             'pop': 0,
#             'pressure': 1009,
#             'sunrise': 1603085741,
#             'sunset': 1603121359,
#             'temp': {'day': 277.72,
#                      'eve': 277.05,
#                      'max': 278.49,
#                      'min': 275.54,
#                      'morn': 276.46,
#                      'night': 275.54},
#             'uvi': 0.78,
#             'weather': [{'description': 'clear sky',
#                          'icon': '01d',
#                          'id': 800,
#                          'main': 'Clear'}],
#             'wind_deg': 315,
#             'wind_speed': 6.93},
#            {'clouds': 100,
#             'dew_point': 272.37,
#             'dt': 1603188000,
#             'feels_like': {'day': 273.62,
#                            'eve': 274.27,
#                            'morn': 270.57,
#                            'night': 277.26},
#             'humidity': 74,
#             'pop': 1,
#             'pressure': 1019,
#             'rain': 4.18,
#             'sunrise': 1603172287,
#             'sunset': 1603207593,
#             'temp': {'day': 276.99,
#                      'eve': 279.13,
#                      'max': 280.44,
#                      'min': 274.09,
#                      'morn': 274.09,
#                      'night': 280.44},
#             'uvi': 0.73,
#             'weather': [{'description': 'moderate rain',
#                          'icon': '10d',
#                          'id': 501,
#                          'main': 'Rain'}],
#             'wind_deg': 159,
#             'wind_speed': 1.9},
#            {'clouds': 98,
#             'dew_point': 280.4,
#             'dt': 1603274400,
#             'feels_like': {'day': 279.4,
#                            'eve': 281.25,
#                            'morn': 277.53,
#                            'night': 281.28},
#             'humidity': 88,
#             'pop': 1,
#             'pressure': 1005,
#             'rain': 3.62,
#             'sunrise': 1603258833,
#             'sunset': 1603293828,
#             'temp': {'day': 282.2,
#                      'eve': 283.44,
#                      'max': 284.1,
#                      'min': 280.23,
#                      'morn': 280.23,
#                      'night': 284.1},
#             'uvi': 0.75,
#             'weather': [{'description': 'moderate rain',
#                          'icon': '10d',
#                          'id': 501,
#                          'main': 'Rain'}],
#             'wind_deg': 212,
#             'wind_speed': 3.06},
#            {'clouds': 96,
#             'dew_point': 282.91,
#             'dt': 1603360800,
#             'feels_like': {'day': 280.57,
#                            'eve': 280.07,
#                            'morn': 282.25,
#                            'night': 275.65},
#             'humidity': 82,
#             'pop': 1,
#             'pressure': 993,
#             'rain': 8.22,
#             'sunrise': 1603345379,
#             'sunset': 1603380065,
#             'temp': {'day': 285.83,
#                      'eve': 284.86,
#                      'max': 286.38,
#                      'min': 282.19,
#                      'morn': 284.75,
#                      'night': 282.19},
#             'uvi': 0.7,
#             'weather': [{'description': 'moderate rain',
#                          'icon': '10d',
#                          'id': 501,
#                          'main': 'Rain'}],
#             'wind_deg': 260,
#             'wind_speed': 7.46},
#            {'clouds': 0,
#             'dew_point': 272.24,
#             'dt': 1603447200,
#             'feels_like': {'day': 273.04,
#                            'eve': 273.88,
#                            'morn': 275.52,
#                            'night': 272.42},
#             'humidity': 64,
#             'pop': 0.58,
#             'pressure': 1002,
#             'rain': 0.68,
#             'sunrise': 1603431926,
#             'sunset': 1603466302,
#             'temp': {'day': 279.1,
#                      'eve': 278.86,
#                      'max': 282.95,
#                      'min': 276.38,
#                      'morn': 280.51,
#                      'night': 276.38},
#             'uvi': 0.64,
#             'weather': [{'description': 'light rain',
#                          'icon': '10d',
#                          'id': 500,
#                          'main': 'Rain'}],
#             'wind_deg': 304,
#             'wind_speed': 5.75},
#            {'clouds': 56,
#             'dew_point': 272.08,
#             'dt': 1603533600,
#             'feels_like': {'day': 274.5,
#                            'eve': 275.1,
#                            'morn': 271.44,
#                            'night': 275.31},
#             'humidity': 70,
#             'pop': 0,
#             'pressure': 1012,
#             'sunrise': 1603518473,
#             'sunset': 1603552540,
#             'temp': {'day': 277.78,
#                      'eve': 278.14,
#                      'max': 279.42,
#                      'min': 274.38,
#                      'morn': 274.83,
#                      'night': 278.03},
#             'uvi': 0.64,
#             'weather': [{'description': 'broken clouds',
#                          'icon': '04d',
#                          'id': 803,
#                          'main': 'Clouds'}],
#             'wind_deg': 266,
#             'wind_speed': 1.77},
#            {'clouds': 89,
#             'dew_point': 277.96,
#             'dt': 1603620000,
#             'feels_like': {'day': 278.09,
#                            'eve': 279.03,
#                            'morn': 275.09,
#                            'night': 278.42},
#             'humidity': 79,
#             'pop': 0,
#             'pressure': 1019,
#             'sunrise': 1603605021,
#             'sunset': 1603638779,
#             'temp': {'day': 281.23,
#                      'eve': 281.55,
#                      'max': 283.2,
#                      'min': 277.24,
#                      'morn': 277.68,
#                      'night': 280.57},
#             'uvi': 0.64,
#             'weather': [{'description': 'overcast clouds',
#                          'icon': '04d',
#                          'id': 804,
#                          'main': 'Clouds'}],
#             'wind_deg': 191,
#             'wind_speed': 2.78},
#            {'clouds': 84,
#             'dew_point': 281.78,
#             'dt': 1603706400,
#             'feels_like': {'day': 280.54,
#                            'eve': 278.19,
#                            'morn': 278.71,
#                            'night': 278.05},
#             'humidity': 86,
#             'pop': 0,
#             'pressure': 1022,
#             'sunrise': 1603691569,
#             'sunset': 1603725020,
#             'temp': {'day': 283.89,
#                      'eve': 283.07,
#                      'max': 284.28,
#                      'min': 280.61,
#                      'morn': 281.04,
#                      'night': 283.15},
#             'uvi': 0.6,
#             'weather': [{'description': 'broken clouds',
#                          'icon': '04d',
#                          'id': 803,
#                          'main': 'Clouds'}],
#             'wind_deg': 160,
#             'wind_speed': 4.29}],
#  'hourly': [{'clouds': 29,
#              'dew_point': 269.33,
#              'dt': 1603123200,
#              'feels_like': 271.63,
#              'humidity': 55,
#              'pop': 0,
#              'pressure': 1012,
#              'temp': 277.05,
#              'visibility': 10000,
#              'weather': [{'description': 'scattered clouds',
#                           'icon': '03n',
#                           'id': 802,
#                           'main': 'Clouds'}],
#              'wind_deg': 317,
#              'wind_speed': 4.12},
#             {'clouds': 32,
#              'dew_point': 270.74,
#              'dt': 1603126800,
#              'feels_like': 271.75,
#              'humidity': 63,
#              'pop': 0,
#              'pressure': 1012,
#              'temp': 276.81,
#              'visibility': 10000,
#              'weather': [{'description': 'scattered clouds',
#                           'icon': '03n',
#                           'id': 802,
#                           'main': 'Clouds'}],
#              'wind_deg': 326,
#              'wind_speed': 3.87},
#             {'clouds': 42,
#              'dew_point': 271.63,
#              'dt': 1603130400,
#              'feels_like': 271.61,
#              'humidity': 70,
#              'pop': 0,
#              'pressure': 1014,
#              'temp': 276.37,
#              'visibility': 10000,
#              'weather': [{'description': 'scattered clouds',
#                           'icon': '03n',
#                           'id': 802,
#                           'main': 'Clouds'}],
#              'wind_deg': 329,
#              'wind_speed': 3.62},
#             {'clouds': 94,
#              'dew_point': 271.98,
#              'dt': 1603134000,
#              'feels_like': 271.33,
#              'humidity': 74,
#              'pop': 0,
#              'pressure': 1015,
#              'temp': 275.99,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 320,
#              'wind_speed': 3.56},
#             {'clouds': 86,
#              'dew_point': 272.22,
#              'dt': 1603137600,
#              'feels_like': 270.85,
#              'humidity': 78,
#              'pop': 0,
#              'pressure': 1015,
#              'temp': 275.53,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 317,
#              'wind_speed': 3.64},
#             {'clouds': 58,
#              'dew_point': 269.45,
#              'dt': 1603141200,
#              'feels_like': 270.45,
#              'humidity': 81,
#              'pop': 0,
#              'pressure': 1016,
#              'temp': 275.12,
#              'visibility': 10000,
#              'weather': [{'description': 'broken clouds',
#                           'icon': '04n',
#                           'id': 803,
#                           'main': 'Clouds'}],
#              'wind_deg': 317,
#              'wind_speed': 3.64},
#             {'clouds': 47,
#              'dew_point': 269.82,
#              'dt': 1603144800,
#              'feels_like': 270.15,
#              'humidity': 84,
#              'pop': 0,
#              'pressure': 1017,
#              'temp': 274.73,
#              'visibility': 10000,
#              'weather': [{'description': 'scattered clouds',
#                           'icon': '03n',
#                           'id': 802,
#                           'main': 'Clouds'}],
#              'wind_deg': 322,
#              'wind_speed': 3.54},
#             {'clouds': 56,
#              'dew_point': 270.14,
#              'dt': 1603148400,
#              'feels_like': 269.99,
#              'humidity': 86,
#              'pop': 0,
#              'pressure': 1017,
#              'temp': 274.4,
#              'visibility': 10000,
#              'weather': [{'description': 'broken clouds',
#                           'icon': '04n',
#                           'id': 803,
#                           'main': 'Clouds'}],
#              'wind_deg': 326,
#              'wind_speed': 3.29},
#             {'clouds': 63,
#              'dew_point': 270.39,
#              'dt': 1603152000,
#              'feels_like': 270.11,
#              'humidity': 88,
#              'pop': 0,
#              'pressure': 1018,
#              'temp': 274.14,
#              'visibility': 10000,
#              'weather': [{'description': 'broken clouds',
#                           'icon': '04n',
#                           'id': 803,
#                           'main': 'Clouds'}],
#              'wind_deg': 322,
#              'wind_speed': 2.76},
#             {'clouds': 100,
#              'dew_point': 270.6,
#              'dt': 1603155600,
#              'feels_like': 270.04,
#              'humidity': 89,
#              'pop': 0,
#              'pressure': 1018,
#              'temp': 274.02,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 307,
#              'wind_speed': 2.7},
#             {'clouds': 100,
#              'dew_point': 270.82,
#              'dt': 1603159200,
#              'feels_like': 270.32,
#              'humidity': 89,
#              'pop': 0,
#              'pressure': 1018,
#              'temp': 274.08,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 306,
#              'wind_speed': 2.39},
#             {'clouds': 100,
#              'dew_point': 270.96,
#              'dt': 1603162800,
#              'feels_like': 270.55,
#              'humidity': 90,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 274.07,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 313,
#              'wind_speed': 2.09},
#             {'clouds': 100,
#              'dew_point': 271,
#              'dt': 1603166400,
#              'feels_like': 270.63,
#              'humidity': 91,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 273.87,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 315,
#              'wind_speed': 1.67},
#             {'clouds': 100,
#              'dew_point': 271.09,
#              'dt': 1603170000,
#              'feels_like': 271.12,
#              'humidity': 90,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 273.97,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 325,
#              'wind_speed': 1.11},
#             {'clouds': 100,
#              'dew_point': 271.25,
#              'dt': 1603173600,
#              'feels_like': 271.73,
#              'humidity': 89,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 274.19,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 336,
#              'wind_speed': 0.56},
#             {'clouds': 100,
#              'dew_point': 271.59,
#              'dt': 1603177200,
#              'feels_like': 272.86,
#              'humidity': 84,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 275.13,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 257,
#              'wind_speed': 0.32},
#             {'clouds': 100,
#              'dew_point': 272.02,
#              'dt': 1603180800,
#              'feels_like': 273.63,
#              'humidity': 78,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 276.2,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 174,
#              'wind_speed': 0.75},
#             {'clouds': 100,
#              'dew_point': 272.37,
#              'dt': 1603184400,
#              'feels_like': 273.62,
#              'humidity': 74,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 276.99,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 159,
#              'wind_speed': 1.9},
#             {'clouds': 100,
#              'dew_point': 272.56,
#              'dt': 1603188000,
#              'feels_like': 274.15,
#              'humidity': 69,
#              'pop': 0,
#              'pressure': 1019,
#              'temp': 278.04,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 163,
#              'wind_speed': 2.66},
#             {'clouds': 100,
#              'dew_point': 272.3,
#              'dt': 1603191600,
#              'feels_like': 274.64,
#              'humidity': 65,
#              'pop': 0,
#              'pressure': 1018,
#              'temp': 279,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 171,
#              'wind_speed': 3.34},
#             {'clouds': 100,
#              'dew_point': 273.45,
#              'dt': 1603195200,
#              'feels_like': 274.43,
#              'humidity': 66,
#              'pop': 0,
#              'pressure': 1018,
#              'temp': 279.2,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 172,
#              'wind_speed': 4.01},
#             {'clouds': 100,
#              'dew_point': 275.6,
#              'dt': 1603198800,
#              'feels_like': 273.67,
#              'humidity': 81,
#              'pop': 0.75,
#              'pressure': 1017,
#              'rain': {'1h': 0.18},
#              'temp': 278.52,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10d',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 158,
#              'wind_speed': 4.63},
#             {'clouds': 100,
#              'dew_point': 276.95,
#              'dt': 1603202400,
#              'feels_like': 273.89,
#              'humidity': 88,
#              'pop': 0.92,
#              'pressure': 1016,
#              'rain': {'1h': 0.44},
#              'temp': 278.72,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10d',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 159,
#              'wind_speed': 4.94},
#             {'clouds': 100,
#              'dew_point': 277.59,
#              'dt': 1603206000,
#              'feels_like': 274.27,
#              'humidity': 89,
#              'pop': 1,
#              'pressure': 1015,
#              'rain': {'1h': 0.63},
#              'temp': 279.13,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10d',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 158,
#              'wind_speed': 5.14},
#             {'clouds': 100,
#              'dew_point': 277.98,
#              'dt': 1603209600,
#              'feels_like': 274.6,
#              'humidity': 90,
#              'pop': 1,
#              'pressure': 1014,
#              'rain': {'1h': 0.58},
#              'temp': 279.47,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 163,
#              'wind_speed': 5.3},
#             {'clouds': 100,
#              'dew_point': 278.55,
#              'dt': 1603213200,
#              'feels_like': 275.38,
#              'humidity': 91,
#              'pop': 1,
#              'pressure': 1013,
#              'rain': {'1h': 0.72},
#              'temp': 279.91,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 161,
#              'wind_speed': 4.98},
#             {'clouds': 100,
#              'dew_point': 279.39,
#              'dt': 1603216800,
#              'feels_like': 277.08,
#              'humidity': 93,
#              'pop': 1,
#              'pressure': 1012,
#              'rain': {'1h': 0.51},
#              'temp': 280.38,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 158,
#              'wind_speed': 3.45},
#             {'clouds': 100,
#              'dew_point': 279.4,
#              'dt': 1603220400,
#              'feels_like': 277.29,
#              'humidity': 92,
#              'pop': 1,
#              'pressure': 1011,
#              'rain': {'1h': 0.24},
#              'temp': 280.46,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 204,
#              'wind_speed': 3.25},
#             {'clouds': 100,
#              'dew_point': 279.1,
#              'dt': 1603224000,
#              'feels_like': 277.5,
#              'humidity': 92,
#              'pop': 1,
#              'pressure': 1011,
#              'rain': {'1h': 0.4},
#              'temp': 280.24,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 202,
#              'wind_speed': 2.56},
#             {'clouds': 100,
#              'dew_point': 279.42,
#              'dt': 1603227600,
#              'feels_like': 277.26,
#              'humidity': 93,
#              'pop': 1,
#              'pressure': 1010,
#              'rain': {'1h': 0.48},
#              'temp': 280.44,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 208,
#              'wind_speed': 3.31},
#             {'clouds': 100,
#              'dew_point': 279.65,
#              'dt': 1603231200,
#              'feels_like': 277.51,
#              'humidity': 92,
#              'pop': 1,
#              'pressure': 1009,
#              'rain': {'1h': 0.52},
#              'temp': 280.76,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 210,
#              'wind_speed': 3.45},
#             {'clouds': 100,
#              'dew_point': 279.59,
#              'dt': 1603234800,
#              'feels_like': 277.66,
#              'humidity': 92,
#              'pop': 1,
#              'pressure': 1008,
#              'rain': {'1h': 0.82},
#              'temp': 280.71,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 216,
#              'wind_speed': 3.15},
#             {'clouds': 100,
#              'dew_point': 279.37,
#              'dt': 1603238400,
#              'feels_like': 278.16,
#              'humidity': 91,
#              'pop': 1,
#              'pressure': 1008,
#              'rain': {'1h': 0.39},
#              'temp': 280.72,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 209,
#              'wind_speed': 2.4},
#             {'clouds': 100,
#              'dew_point': 279.1,
#              'dt': 1603242000,
#              'feels_like': 278,
#              'humidity': 89,
#              'pop': 0.68,
#              'pressure': 1007,
#              'temp': 280.65,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 214,
#              'wind_speed': 2.42},
#             {'clouds': 100,
#              'dew_point': 278.75,
#              'dt': 1603245600,
#              'feels_like': 277.54,
#              'humidity': 91,
#              'pop': 0.52,
#              'pressure': 1006,
#              'temp': 280.08,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 216,
#              'wind_speed': 2.19},
#             {'clouds': 100,
#              'dew_point': 278.96,
#              'dt': 1603249200,
#              'feels_like': 277.53,
#              'humidity': 91,
#              'pop': 0.36,
#              'pressure': 1006,
#              'rain': {'1h': 0.12},
#              'temp': 280.23,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10n',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 214,
#              'wind_speed': 2.46},
#             {'clouds': 100,
#              'dew_point': 279.31,
#              'dt': 1603252800,
#              'feels_like': 277.77,
#              'humidity': 92,
#              'pop': 0.25,
#              'pressure': 1006,
#              'temp': 280.49,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 200,
#              'wind_speed': 2.61},
#             {'clouds': 100,
#              'dew_point': 279.64,
#              'dt': 1603256400,
#              'feels_like': 278.16,
#              'humidity': 92,
#              'pop': 0.17,
#              'pressure': 1005,
#              'temp': 280.72,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04n',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 212,
#              'wind_speed': 2.46},
#             {'clouds': 96,
#              'dew_point': 279.29,
#              'dt': 1603260000,
#              'feels_like': 277.88,
#              'humidity': 93,
#              'pop': 0.07,
#              'pressure': 1005,
#              'temp': 280.34,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 201,
#              'wind_speed': 2.25},
#             {'clouds': 97,
#              'dew_point': 279.5,
#              'dt': 1603263600,
#              'feels_like': 277.75,
#              'humidity': 91,
#              'pop': 0.01,
#              'pressure': 1005,
#              'temp': 280.74,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 210,
#              'wind_speed': 3.03},
#             {'clouds': 98,
#              'dew_point': 279.92,
#              'dt': 1603267200,
#              'feels_like': 279.21,
#              'humidity': 88,
#              'pop': 0,
#              'pressure': 1005,
#              'temp': 281.67,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 205,
#              'wind_speed': 2.41},
#             {'clouds': 98,
#              'dew_point': 280.4,
#              'dt': 1603270800,
#              'feels_like': 279.4,
#              'humidity': 88,
#              'pop': 0.35,
#              'pressure': 1005,
#              'rain': {'1h': 0.16},
#              'temp': 282.2,
#              'visibility': 10000,
#              'weather': [{'description': 'light rain',
#                           'icon': '10d',
#                           'id': 500,
#                           'main': 'Rain'}],
#              'wind_deg': 212,
#              'wind_speed': 3.06},
#             {'clouds': 96,
#              'dew_point': 280.88,
#              'dt': 1603274400,
#              'feels_like': 280.01,
#              'humidity': 88,
#              'pop': 0.11,
#              'pressure': 1006,
#              'temp': 282.69,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 208,
#              'wind_speed': 3.05},
#             {'clouds': 96,
#              'dew_point': 281.32,
#              'dt': 1603278000,
#              'feels_like': 280.37,
#              'humidity': 88,
#              'pop': 0.11,
#              'pressure': 1006,
#              'temp': 283.15,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 199,
#              'wind_speed': 3.35},
#             {'clouds': 95,
#              'dew_point': 281.89,
#              'dt': 1603281600,
#              'feels_like': 281.43,
#              'humidity': 86,
#              'pop': 0.07,
#              'pressure': 1005,
#              'temp': 283.99,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 198,
#              'wind_speed': 3.2},
#             {'clouds': 100,
#              'dew_point': 282.21,
#              'dt': 1603285200,
#              'feels_like': 281.52,
#              'humidity': 87,
#              'pop': 0,
#              'pressure': 1005,
#              'temp': 284.17,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 209,
#              'wind_speed': 3.46},
#             {'clouds': 100,
#              'dew_point': 282.37,
#              'dt': 1603288800,
#              'feels_like': 281.55,
#              'humidity': 90,
#              'pop': 0,
#              'pressure': 1005,
#              'temp': 283.84,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 214,
#              'wind_speed': 3.01},
#             {'clouds': 100,
#              'dew_point': 282.34,
#              'dt': 1603292400,
#              'feels_like': 281.25,
#              'humidity': 92,
#              'pop': 0,
#              'pressure': 1004,
#              'temp': 283.44,
#              'visibility': 10000,
#              'weather': [{'description': 'overcast clouds',
#                           'icon': '04d',
#                           'id': 804,
#                           'main': 'Clouds'}],
#              'wind_deg': 211,
#              'wind_speed': 2.84}],
#  'lat': 59.33,
#  'lon': 18.06,
#  'minutely': [{'dt': 1603124280, 'precipitation': 0},
#               {'dt': 1603124340, 'precipitation': 0},
#               {'dt': 1603124400, 'precipitation': 0},
#               {'dt': 1603124460, 'precipitation': 0},
#               {'dt': 1603124520, 'precipitation': 0},
#               {'dt': 1603124580, 'precipitation': 0},
#               {'dt': 1603124640, 'precipitation': 0},
#               {'dt': 1603124700, 'precipitation': 0},
#               {'dt': 1603124760, 'precipitation': 0},
#               {'dt': 1603124820, 'precipitation': 0},
#               {'dt': 1603124880, 'precipitation': 0},
#               {'dt': 1603124940, 'precipitation': 0},
#               {'dt': 1603125000, 'precipitation': 0},
#               {'dt': 1603125060, 'precipitation': 0},
#               {'dt': 1603125120, 'precipitation': 0},
#               {'dt': 1603125180, 'precipitation': 0},
#               {'dt': 1603125240, 'precipitation': 0},
#               {'dt': 1603125300, 'precipitation': 0},
#               {'dt': 1603125360, 'precipitation': 0},
#               {'dt': 1603125420, 'precipitation': 0},
#               {'dt': 1603125480, 'precipitation': 0},
#               {'dt': 1603125540, 'precipitation': 0},
#               {'dt': 1603125600, 'precipitation': 0},
#               {'dt': 1603125660, 'precipitation': 0},
#               {'dt': 1603125720, 'precipitation': 0},
#               {'dt': 1603125780, 'precipitation': 0},
#               {'dt': 1603125840, 'precipitation': 0},
#               {'dt': 1603125900, 'precipitation': 0},
#               {'dt': 1603125960, 'precipitation': 0},
#               {'dt': 1603126020, 'precipitation': 0},
#               {'dt': 1603126080, 'precipitation': 0},
#               {'dt': 1603126140, 'precipitation': 0},
#               {'dt': 1603126200, 'precipitation': 0},
#               {'dt': 1603126260, 'precipitation': 0},
#               {'dt': 1603126320, 'precipitation': 0},
#               {'dt': 1603126380, 'precipitation': 0},
#               {'dt': 1603126440, 'precipitation': 0},
#               {'dt': 1603126500, 'precipitation': 0},
#               {'dt': 1603126560, 'precipitation': 0},
#               {'dt': 1603126620, 'precipitation': 0},
#               {'dt': 1603126680, 'precipitation': 0},
#               {'dt': 1603126740, 'precipitation': 0},
#               {'dt': 1603126800, 'precipitation': 0},
#               {'dt': 1603126860, 'precipitation': 0},
#               {'dt': 1603126920, 'precipitation': 0},
#               {'dt': 1603126980, 'precipitation': 0},
#               {'dt': 1603127040, 'precipitation': 0},
#               {'dt': 1603127100, 'precipitation': 0},
#               {'dt': 1603127160, 'precipitation': 0},
#               {'dt': 1603127220, 'precipitation': 0},
#               {'dt': 1603127280, 'precipitation': 0},
#               {'dt': 1603127340, 'precipitation': 0},
#               {'dt': 1603127400, 'precipitation': 0},
#               {'dt': 1603127460, 'precipitation': 0},
#               {'dt': 1603127520, 'precipitation': 0},
#               {'dt': 1603127580, 'precipitation': 0},
#               {'dt': 1603127640, 'precipitation': 0},
#               {'dt': 1603127700, 'precipitation': 0},
#               {'dt': 1603127760, 'precipitation': 0},
#               {'dt': 1603127820, 'precipitation': 0},
#               {'dt': 1603127880, 'precipitation': 0}],
#  'timezone': 'Europe/Stockholm',
#  'timezone_offset': 7200}

# %%
#Create Kafka Producer
ip = 'localhost'
producer = KafkaProducer(bootstrap_servers=[ip+':9092'],
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
producer.send("weather",json_data)

# %% [markdown]
# # Consumer

# %%
# What is the point of this fucntion???? - Bharat
def connect_kafka_producer(server):
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=[server], api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _producer

# %%
kafka_producer = connect_kafka_producer(ip)

# %%
topic_name = 'weather'
consumer = KafkaConsumer(topic_name,
                         auto_offset_reset='earliest',
                         bootstrap_servers=[ip],
                         api_version=(0, 10, 0),
                         value_deserializer = json.loads,
                         consumer_timeout_ms=1000)

for msg in consumer:
    pprint(msg.value) #.key.decode("utf-8"), msg.value)
# Out:
# {'clouds': 29,
#  'dew_point': 269.33,
#  'dt': 1603123200,
#  'feels_like': 271.63,
#  'humidity': 55,
#  'pop': 0,
#  'pressure': 1012,
#  'temp': 277.05,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 317,
#  'wind_speed': 4.12}
# {'clouds': 32,
#  'dew_point': 270.74,
#  'dt': 1603126800,
#  'feels_like': 271.75,
#  'humidity': 63,
#  'pop': 0,
#  'pressure': 1012,
#  'temp': 276.81,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 326,
#  'wind_speed': 3.87}
# {'clouds': 42,
#  'dew_point': 271.63,
#  'dt': 1603130400,
#  'feels_like': 271.61,
#  'humidity': 70,
#  'pop': 0,
#  'pressure': 1014,
#  'temp': 276.37,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 329,
#  'wind_speed': 3.62}
# {'clouds': 94,
#  'dew_point': 271.98,
#  'dt': 1603134000,
#  'feels_like': 271.33,
#  'humidity': 74,
#  'pop': 0,
#  'pressure': 1015,
#  'temp': 275.99,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 320,
#  'wind_speed': 3.56}
# {'clouds': 86,
#  'dew_point': 272.22,
#  'dt': 1603137600,
#  'feels_like': 270.85,
#  'humidity': 78,
#  'pop': 0,
#  'pressure': 1015,
#  'temp': 275.53,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 317,
#  'wind_speed': 3.64}
# {'clouds': 58,
#  'dew_point': 269.45,
#  'dt': 1603141200,
#  'feels_like': 270.45,
#  'humidity': 81,
#  'pop': 0,
#  'pressure': 1016,
#  'temp': 275.12,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind_deg': 317,
#  'wind_speed': 3.64}
# {'clouds': 47,
#  'dew_point': 269.82,
#  'dt': 1603144800,
#  'feels_like': 270.15,
#  'humidity': 84,
#  'pop': 0,
#  'pressure': 1017,
#  'temp': 274.73,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 322,
#  'wind_speed': 3.54}
# {'clouds': 56,
#  'dew_point': 270.14,
#  'dt': 1603148400,
#  'feels_like': 269.99,
#  'humidity': 86,
#  'pop': 0,
#  'pressure': 1017,
#  'temp': 274.4,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind_deg': 326,
#  'wind_speed': 3.29}
# {'clouds': 63,
#  'dew_point': 270.39,
#  'dt': 1603152000,
#  'feels_like': 270.11,
#  'humidity': 88,
#  'pop': 0,
#  'pressure': 1018,
#  'temp': 274.14,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind_deg': 322,
#  'wind_speed': 2.76}
# {'clouds': 100,
#  'dew_point': 270.6,
#  'dt': 1603155600,
#  'feels_like': 270.04,
#  'humidity': 89,
#  'pop': 0,
#  'pressure': 1018,
#  'temp': 274.02,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 307,
#  'wind_speed': 2.7}
# {'clouds': 29,
#  'dew_point': 269.33,
#  'dt': 1603123200,
#  'feels_like': 271.63,
#  'humidity': 55,
#  'pop': 0,
#  'pressure': 1012,
#  'temp': 277.05,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 317,
#  'wind_speed': 4.12}
# {'clouds': 32,
#  'dew_point': 270.74,
#  'dt': 1603126800,
#  'feels_like': 271.75,
#  'humidity': 63,
#  'pop': 0,
#  'pressure': 1012,
#  'temp': 276.81,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 326,
#  'wind_speed': 3.87}
# {'clouds': 42,
#  'dew_point': 271.63,
#  'dt': 1603130400,
#  'feels_like': 271.61,
#  'humidity': 70,
#  'pop': 0,
#  'pressure': 1014,
#  'temp': 276.37,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 329,
#  'wind_speed': 3.62}
# {'clouds': 94,
#  'dew_point': 271.98,
#  'dt': 1603134000,
#  'feels_like': 271.33,
#  'humidity': 74,
#  'pop': 0,
#  'pressure': 1015,
#  'temp': 275.99,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 320,
#  'wind_speed': 3.56}
# {'clouds': 86,
#  'dew_point': 272.22,
#  'dt': 1603137600,
#  'feels_like': 270.85,
#  'humidity': 78,
#  'pop': 0,
#  'pressure': 1015,
#  'temp': 275.53,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 317,
#  'wind_speed': 3.64}
# {'clouds': 58,
#  'dew_point': 269.45,
#  'dt': 1603141200,
#  'feels_like': 270.45,
#  'humidity': 81,
#  'pop': 0,
#  'pressure': 1016,
#  'temp': 275.12,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind_deg': 317,
#  'wind_speed': 3.64}
# {'clouds': 47,
#  'dew_point': 269.82,
#  'dt': 1603144800,
#  'feels_like': 270.15,
#  'humidity': 84,
#  'pop': 0,
#  'pressure': 1017,
#  'temp': 274.73,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind_deg': 322,
#  'wind_speed': 3.54}
# {'clouds': 56,
#  'dew_point': 270.14,
#  'dt': 1603148400,
#  'feels_like': 269.99,
#  'humidity': 86,
#  'pop': 0,
#  'pressure': 1017,
#  'temp': 274.4,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind_deg': 326,
#  'wind_speed': 3.29}
# {'clouds': 63,
#  'dew_point': 270.39,
#  'dt': 1603152000,
#  'feels_like': 270.11,
#  'humidity': 88,
#  'pop': 0,
#  'pressure': 1018,
#  'temp': 274.14,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind_deg': 322,
#  'wind_speed': 2.76}
# {'clouds': 100,
#  'dew_point': 270.6,
#  'dt': 1603155600,
#  'feels_like': 270.04,
#  'humidity': 89,
#  'pop': 0,
#  'pressure': 1018,
#  'temp': 274.02,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 307,
#  'wind_speed': 2.7}
# {'clouds': 100,
#  'dew_point': 270.82,
#  'dt': 1603159200,
#  'feels_like': 270.32,
#  'humidity': 89,
#  'pop': 0,
#  'pressure': 1018,
#  'temp': 274.08,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 306,
#  'wind_speed': 2.39}
# {'clouds': 100,
#  'dew_point': 270.96,
#  'dt': 1603162800,
#  'feels_like': 270.55,
#  'humidity': 90,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 274.07,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 313,
#  'wind_speed': 2.09}
# {'clouds': 100,
#  'dew_point': 271,
#  'dt': 1603166400,
#  'feels_like': 270.63,
#  'humidity': 91,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 273.87,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 315,
#  'wind_speed': 1.67}
# {'clouds': 100,
#  'dew_point': 271.09,
#  'dt': 1603170000,
#  'feels_like': 271.12,
#  'humidity': 90,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 273.97,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 325,
#  'wind_speed': 1.11}
# {'clouds': 100,
#  'dew_point': 271.25,
#  'dt': 1603173600,
#  'feels_like': 271.73,
#  'humidity': 89,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 274.19,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 336,
#  'wind_speed': 0.56}
# {'clouds': 100,
#  'dew_point': 271.59,
#  'dt': 1603177200,
#  'feels_like': 272.86,
#  'humidity': 84,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 275.13,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 257,
#  'wind_speed': 0.32}
# {'clouds': 100,
#  'dew_point': 272.02,
#  'dt': 1603180800,
#  'feels_like': 273.63,
#  'humidity': 78,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 276.2,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 174,
#  'wind_speed': 0.75}
# {'clouds': 100,
#  'dew_point': 272.37,
#  'dt': 1603184400,
#  'feels_like': 273.62,
#  'humidity': 74,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 276.99,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 159,
#  'wind_speed': 1.9}
# {'clouds': 100,
#  'dew_point': 272.56,
#  'dt': 1603188000,
#  'feels_like': 274.15,
#  'humidity': 69,
#  'pop': 0,
#  'pressure': 1019,
#  'temp': 278.04,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 163,
#  'wind_speed': 2.66}
# {'clouds': 100,
#  'dew_point': 272.3,
#  'dt': 1603191600,
#  'feels_like': 274.64,
#  'humidity': 65,
#  'pop': 0,
#  'pressure': 1018,
#  'temp': 279,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 171,
#  'wind_speed': 3.34}
# {'clouds': 100,
#  'dew_point': 273.45,
#  'dt': 1603195200,
#  'feels_like': 274.43,
#  'humidity': 66,
#  'pop': 0,
#  'pressure': 1018,
#  'temp': 279.2,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 172,
#  'wind_speed': 4.01}
# {'clouds': 100,
#  'dew_point': 275.6,
#  'dt': 1603198800,
#  'feels_like': 273.67,
#  'humidity': 81,
#  'pop': 0.75,
#  'pressure': 1017,
#  'rain': {'1h': 0.18},
#  'temp': 278.52,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 158,
#  'wind_speed': 4.63}
# {'clouds': 100,
#  'dew_point': 276.95,
#  'dt': 1603202400,
#  'feels_like': 273.89,
#  'humidity': 88,
#  'pop': 0.92,
#  'pressure': 1016,
#  'rain': {'1h': 0.44},
#  'temp': 278.72,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 159,
#  'wind_speed': 4.94}
# {'clouds': 100,
#  'dew_point': 277.59,
#  'dt': 1603206000,
#  'feels_like': 274.27,
#  'humidity': 89,
#  'pop': 1,
#  'pressure': 1015,
#  'rain': {'1h': 0.63},
#  'temp': 279.13,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 158,
#  'wind_speed': 5.14}
# {'clouds': 100,
#  'dew_point': 277.98,
#  'dt': 1603209600,
#  'feels_like': 274.6,
#  'humidity': 90,
#  'pop': 1,
#  'pressure': 1014,
#  'rain': {'1h': 0.58},
#  'temp': 279.47,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 163,
#  'wind_speed': 5.3}
# {'clouds': 100,
#  'dew_point': 278.55,
#  'dt': 1603213200,
#  'feels_like': 275.38,
#  'humidity': 91,
#  'pop': 1,
#  'pressure': 1013,
#  'rain': {'1h': 0.72},
#  'temp': 279.91,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 161,
#  'wind_speed': 4.98}
# {'clouds': 100,
#  'dew_point': 279.39,
#  'dt': 1603216800,
#  'feels_like': 277.08,
#  'humidity': 93,
#  'pop': 1,
#  'pressure': 1012,
#  'rain': {'1h': 0.51},
#  'temp': 280.38,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 158,
#  'wind_speed': 3.45}
# {'clouds': 100,
#  'dew_point': 279.4,
#  'dt': 1603220400,
#  'feels_like': 277.29,
#  'humidity': 92,
#  'pop': 1,
#  'pressure': 1011,
#  'rain': {'1h': 0.24},
#  'temp': 280.46,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 204,
#  'wind_speed': 3.25}
# {'clouds': 100,
#  'dew_point': 279.1,
#  'dt': 1603224000,
#  'feels_like': 277.5,
#  'humidity': 92,
#  'pop': 1,
#  'pressure': 1011,
#  'rain': {'1h': 0.4},
#  'temp': 280.24,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 202,
#  'wind_speed': 2.56}
# {'clouds': 100,
#  'dew_point': 279.42,
#  'dt': 1603227600,
#  'feels_like': 277.26,
#  'humidity': 93,
#  'pop': 1,
#  'pressure': 1010,
#  'rain': {'1h': 0.48},
#  'temp': 280.44,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 208,
#  'wind_speed': 3.31}
# {'clouds': 100,
#  'dew_point': 279.65,
#  'dt': 1603231200,
#  'feels_like': 277.51,
#  'humidity': 92,
#  'pop': 1,
#  'pressure': 1009,
#  'rain': {'1h': 0.52},
#  'temp': 280.76,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 210,
#  'wind_speed': 3.45}
# {'clouds': 100,
#  'dew_point': 279.59,
#  'dt': 1603234800,
#  'feels_like': 277.66,
#  'humidity': 92,
#  'pop': 1,
#  'pressure': 1008,
#  'rain': {'1h': 0.82},
#  'temp': 280.71,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 216,
#  'wind_speed': 3.15}
# {'clouds': 100,
#  'dew_point': 279.37,
#  'dt': 1603238400,
#  'feels_like': 278.16,
#  'humidity': 91,
#  'pop': 1,
#  'pressure': 1008,
#  'rain': {'1h': 0.39},
#  'temp': 280.72,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 209,
#  'wind_speed': 2.4}
# {'clouds': 100,
#  'dew_point': 279.1,
#  'dt': 1603242000,
#  'feels_like': 278,
#  'humidity': 89,
#  'pop': 0.68,
#  'pressure': 1007,
#  'temp': 280.65,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 214,
#  'wind_speed': 2.42}
# {'clouds': 100,
#  'dew_point': 278.75,
#  'dt': 1603245600,
#  'feels_like': 277.54,
#  'humidity': 91,
#  'pop': 0.52,
#  'pressure': 1006,
#  'temp': 280.08,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 216,
#  'wind_speed': 2.19}
# {'clouds': 100,
#  'dew_point': 278.96,
#  'dt': 1603249200,
#  'feels_like': 277.53,
#  'humidity': 91,
#  'pop': 0.36,
#  'pressure': 1006,
#  'rain': {'1h': 0.12},
#  'temp': 280.23,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 214,
#  'wind_speed': 2.46}
# {'clouds': 100,
#  'dew_point': 279.31,
#  'dt': 1603252800,
#  'feels_like': 277.77,
#  'humidity': 92,
#  'pop': 0.25,
#  'pressure': 1006,
#  'temp': 280.49,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 200,
#  'wind_speed': 2.61}
# {'clouds': 100,
#  'dew_point': 279.64,
#  'dt': 1603256400,
#  'feels_like': 278.16,
#  'humidity': 92,
#  'pop': 0.17,
#  'pressure': 1005,
#  'temp': 280.72,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 212,
#  'wind_speed': 2.46}
# {'clouds': 96,
#  'dew_point': 279.29,
#  'dt': 1603260000,
#  'feels_like': 277.88,
#  'humidity': 93,
#  'pop': 0.07,
#  'pressure': 1005,
#  'temp': 280.34,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 201,
#  'wind_speed': 2.25}
# {'clouds': 97,
#  'dew_point': 279.5,
#  'dt': 1603263600,
#  'feels_like': 277.75,
#  'humidity': 91,
#  'pop': 0.01,
#  'pressure': 1005,
#  'temp': 280.74,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 210,
#  'wind_speed': 3.03}
# {'clouds': 98,
#  'dew_point': 279.92,
#  'dt': 1603267200,
#  'feels_like': 279.21,
#  'humidity': 88,
#  'pop': 0,
#  'pressure': 1005,
#  'temp': 281.67,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 205,
#  'wind_speed': 2.41}
# {'clouds': 98,
#  'dew_point': 280.4,
#  'dt': 1603270800,
#  'feels_like': 279.4,
#  'humidity': 88,
#  'pop': 0.35,
#  'pressure': 1005,
#  'rain': {'1h': 0.16},
#  'temp': 282.2,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind_deg': 212,
#  'wind_speed': 3.06}
# {'clouds': 96,
#  'dew_point': 280.88,
#  'dt': 1603274400,
#  'feels_like': 280.01,
#  'humidity': 88,
#  'pop': 0.11,
#  'pressure': 1006,
#  'temp': 282.69,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 208,
#  'wind_speed': 3.05}
# {'clouds': 96,
#  'dew_point': 281.32,
#  'dt': 1603278000,
#  'feels_like': 280.37,
#  'humidity': 88,
#  'pop': 0.11,
#  'pressure': 1006,
#  'temp': 283.15,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 199,
#  'wind_speed': 3.35}
# {'clouds': 95,
#  'dew_point': 281.89,
#  'dt': 1603281600,
#  'feels_like': 281.43,
#  'humidity': 86,
#  'pop': 0.07,
#  'pressure': 1005,
#  'temp': 283.99,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 198,
#  'wind_speed': 3.2}
# {'clouds': 100,
#  'dew_point': 282.21,
#  'dt': 1603285200,
#  'feels_like': 281.52,
#  'humidity': 87,
#  'pop': 0,
#  'pressure': 1005,
#  'temp': 284.17,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 209,
#  'wind_speed': 3.46}
# {'clouds': 100,
#  'dew_point': 282.37,
#  'dt': 1603288800,
#  'feels_like': 281.55,
#  'humidity': 90,
#  'pop': 0,
#  'pressure': 1005,
#  'temp': 283.84,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 214,
#  'wind_speed': 3.01}
# {'clouds': 100,
#  'dew_point': 282.34,
#  'dt': 1603292400,
#  'feels_like': 281.25,
#  'humidity': 92,
#  'pop': 0,
#  'pressure': 1004,
#  'temp': 283.44,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind_deg': 211,
#  'wind_speed': 2.84}
